# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import pickle

from sklearn.metrics.pairwise import cosine_similarity

# %%
books=pd.read_csv("data/Books.csv")
users=pd.read_csv("data/Users.csv")
ratings=pd.read_csv("data/Ratings.csv")
# Out:
# C:\Users\Monish\AppData\Local\Temp\ipykernel_3724\4171821992.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("data/Books.csv")

# %%
print("books data",books.shape)
print("users data",users.shape)
print("ratings data",ratings.shape)
# Out:
# books data (271360, 8)
# users data (278858, 3)
# ratings data (1149780, 3)

# %%
df=ratings.merge(books,on='ISBN')

# %%
number_of_rating=df.groupby('Book-Title').count()['Book-Rating'].reset_index().rename(columns={'Book-Rating':'Number-of-Rating'})
number_of_rating
# Out:
#                                                Book-Title  Number-of-Rating
# 0        A Light in the Storm: The Civil War Diary of ...                 4
# 1                                   Always Have Popsicles                 1
# 2                    Apple Magic (The Collector's series)                 1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...                 1
# 4        Beyond IBM: Leadership Marketing and Finance ...                 1
# ...                                                   ...               ...
# 241066                                      Ã?Â?lpiraten.                 2
# 241067                     Ã?Â?rger mit Produkt X. Roman.                 4
# 241068                                Ã?Â?sterlich leben.                 1
# 241069                              Ã?Â?stlich der Berge.                 3
# 241070                                  Ã?Â?thique en toc                 2
#
# [241071 rows x 2 columns]

# %%
avg_of_rating=df.groupby('Book-Title')['Book-Rating'].mean().reset_index().rename(columns={'Book-Rating':'Average-Rating'})
avg_of_rating
# Out:
#                                                Book-Title  Average-Rating
# 0        A Light in the Storm: The Civil War Diary of ...        2.250000
# 1                                   Always Have Popsicles        0.000000
# 2                    Apple Magic (The Collector's series)        0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...        8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...        0.000000
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.        0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.        5.250000
# 241068                                Ã?Â?sterlich leben.        7.000000
# 241069                              Ã?Â?stlich der Berge.        2.666667
# 241070                                  Ã?Â?thique en toc        4.000000
#
# [241071 rows x 2 columns]

# %%
populer_books=number_of_rating.merge(avg_of_rating,on='Book-Title')
populer_books=populer_books[populer_books["Number-of-Rating"]>250].sort_values('Average-Rating',ascending=False).head(60)
populer_books
# Out:
#                                                Book-Title  Number-of-Rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)               428
# 80422        Harry Potter and the Goblet of Fire (Book 4)               387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)               278
# 80426   Harry Potter and the Order of the Phoenix (Boo...               347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)               556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...               281
# 187377  The Fellowship of the Ring (The Lord of the Ri...               368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...               575
# 211384     The Two Towers (The Lord of the Rings, Part 2)               260
# 219741                              To Kill a Mockingbird               510
# 183573                                  The Da Vinci Code               898
# ...

# %%
populer_books=populer_books.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Number-of-Rating','Average-Rating','Image-URL-M']]

# %% [markdown]
# # Collaborative Recommendation system

# %%
x=df.groupby('User-ID').count()['Book-Rating']>200
users_who_rate_books=x[x].index

# %%
filtered_rating=df[df['User-ID'].isin(users_who_rate_books)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index

# %%
final_rating=filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
final_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
final_table=final_rating.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating').fillna(0)
final_table.head(50)
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# A Case of Need                                         0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Civil Action                                         0.0     0.0     0.0
# A Day Late and a Dollar Short                          0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Great Deliverance                                    0.0     0.0     0.0
# ...

# %%
similarity_scores=cosine_similarity(final_table)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    try:
        index = np.where(final_table.index == book_name)[0][0]
    except IndexError:
        return "Book not found"
    
    similer_books = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:5]
    
    data = []
    
    for i in similer_books:
        item = []
        temp_df = books[books['Book-Title'] == final_table.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    return data

# %%
import urllib.request
from IPython.display import Image, display

data=recommend("You Belong To Me")

for item in data:
    print("Book Title:", item[0])
    print("Book Author:", item[1])
    
    # Display the image
    display(Image(url=item[2]))

    print("-----------------------------------------")
# Out:
# Book Title: Loves Music, Loves to Dance
# Book Author: Mary Higgins Clark
# <img src="http://images.amazon.com/images/P/0671758896.01.MZZZZZZZ.jpg"/>
# -----------------------------------------
# Book Title: I'll Be Seeing You
# Book Author: Mary Higgins Clark
# <img src="http://images.amazon.com/images/P/0671888587.01.MZZZZZZZ.jpg"/>
# -----------------------------------------
# Book Title: Before I Say Good-Bye
# Book Author: Mary Higgins Clark
# <img src="http://images.amazon.com/images/P/0671004573.01.MZZZZZZZ.jpg"/>
# -----------------------------------------
# Book Title: Daddy's Little Girl
# Book Author: Mary Higgins Clark
# <img src="http://images.amazon.com/images/P/0743206045.01.MZZZZZZZ.jpg"/>
# -----------------------------------------

# %%
pickle.dump(populer_books,open('popular_books.pkl','wb'))

# %%
books.drop_duplicates('Book-Title',inplace=True)

# %%
pickle.dump(final_table,open('final_table.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
